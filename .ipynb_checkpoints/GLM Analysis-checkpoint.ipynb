# %%
# %load_ext autoreload
# %autoreload 2

import json
from dwitracts.glm import DwiTractsGlm
import dwitracts.plot as dwiplot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# GLM Analysis using DwiTractsGlm class

config_file = 'project/config_glm_dmn.json'

def _json_object_hook(d): return namedtuple('X', d.keys())(*d.values())
def json2obj(data): return json.loads(data, object_hook=_json_object_hook)

with open(config_file, 'r') as myfile:
    json_string=myfile.read()
    
params = json.loads(json_string)
params_gen = params['general']
params_glm = params['glm']

with open(params_gen['tracts_config_file'], 'r') as myfile:
    json_string=myfile.read()
    
params['tracts'] = json.loads(json_string)

with open(params_gen['preproc_config_file'], 'r') as myfile:
    json_string=myfile.read()
    
params['preproc'] = json.loads(json_string)

my_glm = DwiTractsGlm( params )

# Initialize the object with the current parameters
assert my_glm.initialize()

# %%
# Fit all specified GLMs and save results to target directory
assert my_glm.fit_glms( clobber=True, verbose=True )

# %%
# Extract distance traces from the GLM results
assert my_glm.extract_distance_traces( clobber=True, verbose=True )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Progress', max=9.0, style=ProgressStyle(description_width…
# Evaluating ACC_L_LOC_L
#    Done glm-age-sex
# Evaluating ACC_L_LOC_R
#    Done glm-age-sex
# Evaluating ACC_L_PCG_L
#    Done glm-age-sex
# Evaluating ACC_L_PCG_R
#    Done glm-age-sex
# Evaluating ACC_L_PCm_L
#    Done glm-age-sex
# Evaluating ACC_L_PCm_R
#    Done glm-age-sex
# Evaluating ACC_L_PFCm_L
#    Done glm-age-sex
# Evaluating ACC_L_PFCm_R
#    Done glm-age-sex
# Evaluating LOC_L_LOC_R
#    Done glm-age-sex
# Evaluating LOC_L_PCG_L
#    Done glm-age-sex
# Evaluating LOC_L_PCG_R
#    Done glm-age-sex
# Evaluating LOC_L_PCm_L
#    No tract found for LOC_L_PCm_L. Skipping.
# Evaluating LOC_L_PCm_R
#    Done glm-age-sex
# Evaluating LOC_L_PFCm_L
#    Done glm-age-sex
# Evaluating LOC_L_PFCm_R
#    Done glm-age-sex
# Evaluating LOC_R_PCG_L
#    Done glm-age-sex
# Evaluating LOC_R_PCG_R
#    Done glm-age-sex
# Evaluating LOC_R_PCm_L
#    No tract found for LOC_R_PCm_L. Skipping.
# Evaluating LOC_R_PCm_R
#    Done glm-age-sex
# Evaluating LOC_R_PFCm_L
#    Done glm-age-sex
# Evaluating LOC_R_PFCm_R
#    Done glm-age-sex
# Evaluating PCG_L_PCG_R
#    Done glm-age-sex
# Evaluating PCG_L_PCm_L
#    No tract found for PCG_L_PCm_L. Skipping.
# Evaluating PCG_L_PCm_R
#    Done glm-age-sex
# Evaluating PCG_L_PFCm_L
#    Done glm-age-sex
# Evaluating PCG_L_PFCm_R
#    Done glm-age-sex
# Evaluating PCG_R_PCm_L
#    Done glm-age-sex
# Evaluating PCG_R_PCm_R
#    Done glm-age-sex
# Evaluating PCG_R_PFCm_L
#    Done glm-age-sex
# Evaluating PCG_R_PFCm_R
#    Done glm-age-sex
# Evaluating PCm_L_PCm_R
#    Done glm-age-sex
# Evaluating PCm_L_PFCm_L
#    Done glm-age-sex
# Evaluating PCm_L_PFCm_R
#    Done glm-age-sex
# Evaluating PCm_R_PFCm_L
#    Done glm-age-sex
# Evaluating PCm_R_PFCm_R
#    Done glm-age-sex
# Evaluating PFCm_L_PFCm_R
#    Done glm-age-sex

# %%
# Extract distance traces with 1D RFT correction from the GLM results
assert my_glm.extract_distance_traces_rft1d( clobber=True, verbose=True, fdr_method='fdr_tsbky', fdr_alpha=0.05 )
# Out:
# glm-age-sex
#  Age
#    No output for LOC_L_PCm_L. Skipping.
#    No output for LOC_R_PCm_L. Skipping.
#    No output for PCG_L_PCm_L. Skipping.
# HBox(children=(FloatProgress(value=0.0, description='Performing cluster inference', max=36.0, style=ProgressSt…
# HBox(children=(FloatProgress(value=0.0, description='Saving results', max=33.0, style=ProgressStyle(descriptio…
#  Sex
#    No output for LOC_L_PCm_L. Skipping.
#    No output for LOC_R_PCm_L. Skipping.
#    No output for PCG_L_PCm_L. Skipping.
# HBox(children=(FloatProgress(value=0.0, description='Performing cluster inference', max=36.0, style=ProgressSt…
# HBox(children=(FloatProgress(value=0.0, description='Saving results', max=33.0, style=ProgressStyle(descriptio…
#  Age*Sex
#    No output for LOC_L_PCm_L. Skipping.
#    No output for LOC_R_PCm_L. Skipping.
#    No output for PCG_L_PCm_L. Skipping.
# HBox(children=(FloatProgress(value=0.0, description='Performing cluster inference', max=36.0, style=ProgressSt…
# HBox(children=(FloatProgress(value=0.0, description='Saving results', max=33.0, style=ProgressStyle(descriptio…
#    Wrote volumes & polylines.
#  Wrote results to /Volumes/AndrewElements/data/nki/tract_stats/dmn/glms/glm-age-sex/summary-max/tcounts-rft.csv

# %%
# Plot t-value distance traces

# Font sizes
params['axis_font'] = 24
params['yticklabel_font'] = 12
params['xticklabel_font'] = 20
params['title_font'] = 28

alpha = 0.05

tract_names = my_glm.tract_names.copy()
tract_names.sort()

# Uncorrected
dwiplot.plot_distance_traces( params, tract_names, alpha=alpha, stat_type='uncorrected' )

# FDR corrected
dwiplot.plot_distance_traces( params, tract_names, alpha=alpha, stat_type='fdr' )

# RFT corrected
dwiplot.plot_distance_traces( params, tract_names, alpha=alpha, stat_type='rft' )

# %%
# Plot scatterplots & violin plots for GLM results

# Specify GLM
glm = 'glm-age-sex'

# Set up parameters
params_plot = {}
params_plot['glm'] = glm
params_plot['alpha'] = 0.05
params_plot['outlier_z'] = params_glm[glm]['outlier_z']
params_plot['stat_type'] = 'rft'
params_plot['axis_font'] = 40
params_plot['marker_size'] = 15
params_plot['line_width'] = 4
params_plot['ticklabel_font'] = 33
params_plot['title_font'] = 28
params_plot['legend_font'] = 40
params_plot['legend_scale'] = 3
params_plot['show_title'] = False
params_plot['show_legend'] = True
params_plot['dimensions'] = (25,20)

# Loop through tracts and call plot function for each
dwiplot.plot_glm_results_all( params_plot, my_glm, verbose=True )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Generating plots', max=45.0, style=ProgressStyle(descript…
#   IPL_L_gwfa_SPL_L_gwfa [Age]: Removed 2 outliers.
# Tract not found: IPL_L_gwfa_dPMC_R_gwfa
# Tract not found: IPL_R_gwfa_dPMC_L_gwfa
# Tract not found: IPL_R_gwfa_vPMC_L_gwfa
# Tract not found: IPS_L_gwfa_IPS_R_gwfa
#   IPS_L_gwfa_SPL_L_gwfa [Age]: Removed 2 outliers.
# Tract not found: IPS_L_gwfa_SPL_R_gwfa
# Tract not found: IPS_L_gwfa_vPMC_R_gwfa
# Tract not found: IPS_R_gwfa_SPL_L_gwfa
# Tract not found: IPS_R_gwfa_dPMC_L_gwfa
# Tract not found: IPS_R_gwfa_vPMC_L_gwfa
# Tract not found: SPL_L_gwfa_SPL_R_gwfa
# Tract not found: SPL_L_gwfa_dPMC_R_gwfa
# Tract not found: SPL_L_gwfa_vPMC_L_gwfa
# Tract not found: SPL_L_gwfa_vPMC_R_gwfa
# Tract not found: SPL_R_gwfa_dPMC_L_gwfa
# Tract not found: SPL_R_gwfa_vPMC_L_gwfa
# Tract not found: SPL_R_gwfa_vPMC_R_gwfa

# %%
# Aggregate tracts into single volumes
my_glm.aggregate_tracts(prefix='tract_final_norm_bidir', op='max', verbose=True)
# Out:
#  Added tract_final_norm_bidir_ACC_L_LOC_L.nii.gz
#  Added tract_final_norm_bidir_ACC_L_LOC_R.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PCG_L.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PCG_R.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PCm_L.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PCm_R.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_ACC_L_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_LOC_L_LOC_R.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PCG_L.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PCG_R.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PCm_L.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PCm_R.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_LOC_L_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PCG_L.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PCG_R.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PCm_L.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PCm_R.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_LOC_R_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_PCG_L_PCG_R.nii.gz
#  Added tract_final_norm_bidir_PCG_L_PCm_L.nii.gz
#  Added tract_final_norm_bidir_PCG_L_PCm_R.nii.gz
#  Added tract_final_norm_bidir_PCG_L_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_PCG_L_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_PCG_R_PCm_L.nii.gz
#  Added tract_final_norm_bidir_PCG_R_PCm_R.nii.gz
#  Added tract_final_norm_bidir_PCG_R_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_PCG_R_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_PCm_L_PCm_R.nii.gz
#  Added tract_final_norm_bidir_PCm_L_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_PCm_L_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_PCm_R_PFCm_L.nii.gz
#  Added tract_final_norm_bidir_PCm_R_PFCm_R.nii.gz
#  Added tract_final_norm_bidir_PFCm_L_PFCm_R.nii.gz
# Output saved to /Volumes/AndrewElements/data/nki/tract_stats/dmn/tract_final_norm_bidir_dmn_All_max.nii.gz
# True

# %%
# Aggregate tracts crossing corpus callosum
cc_img = '/Users/lpzatr/OneDrive - The University of Nottingham/synched/projects/atlases/corpus_callosum_midline.nii'
my_glm.aggregate_tracts(prefix='tract_final_norm_bidir', suffix='_cc', intersects=cc_img, \
                        op='max', threshold=0, verbose=True)
# Out:
#  Added tract_final_norm_bidir_IPL_L_gwfa_IPL_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPL_L_gwfa_IPS_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPL_L_gwfa_SPL_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPL_L_gwfa_vPMC_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPL_R_gwfa_IPS_L_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPL_R_gwfa_SPL_L_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPS_L_gwfa_SPL_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_IPS_L_gwfa_dPMC_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_SPL_R_gwfa_dPMC_L_gwfa.nii.gz
#  Added tract_final_norm_bidir_dPMC_L_gwfa_dPMC_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_dPMC_L_gwfa_vPMC_R_gwfa.nii.gz
#  Added tract_final_norm_bidir_dPMC_R_gwfa_vPMC_L_gwfa.nii.gz
#  Added tract_final_norm_bidir_vPMC_L_gwfa_vPMC_R_gwfa.nii.gz
# Output saved to /Volumes/AndrewElements/data/nki/tract_stats/what-where/tract_final_norm_bidir_what-where_All_max_cc.nii.gz
# True

# %%
# Aggregate stats into single volumes

assert my_glm.aggregate_stats( op='max', pthres=0.05, suffix='-rft', verbose=True, clobber=True )
# Out:
# glm-age-sex
#  Age
#   Added ACC_L_LOC_R_Age.nii.gz [246]
#   Added ACC_L_PCG_R_Age.nii.gz [496]
#   Added ACC_L_PCm_R_Age.nii.gz [557]
#   Added LOC_L_PCG_L_Age.nii.gz [608]
#   Added LOC_L_PFCm_R_Age.nii.gz [254]
#   Added LOC_R_PFCm_R_Age.nii.gz [1385]
#   Added PCG_L_PCG_R_Age.nii.gz [738]
#   Added PCG_L_PCm_R_Age.nii.gz [1770]
#   Added PCG_L_PFCm_L_Age.nii.gz [552]
#   Added PCG_L_PFCm_R_Age.nii.gz [468]
#   Added PCG_R_PCm_L_Age.nii.gz [871]
#   Added PCG_R_PCm_R_Age.nii.gz [1311]
#   Added PCG_R_PFCm_R_Age.nii.gz [233]
#   Added PCm_L_PCm_R_Age.nii.gz [985]
#   Added PCm_L_PFCm_R_Age.nii.gz [549]
#   Added PFCm_L_PFCm_R_Age.nii.gz [1066]
#  Output saved to /Volumes/AndrewElements/data/nki/tract_stats/dmn/glms/glm-age-sex
#  Sex
#   Added ACC_L_PCm_L_Sex.nii.gz [186]
#   Added LOC_L_PCm_R_Sex.nii.gz [1218]
#   Added LOC_L_PFCm_R_Sex.nii.gz [260]
#   Added LOC_R_PCm_R_Sex.nii.gz [755]
#   Added PCm_L_PFCm_L_Sex.nii.gz [155]
#  Output saved to /Volumes/AndrewElements/data/nki/tract_stats/dmn/glms/glm-age-sex
#  Age*Sex
#   Added ACC_L_PFCm_R_AgeXSex.nii.gz [1350]
#   Added LOC_L_PCm_R_AgeXSex.nii.gz [1131]
#   Added LOC_L_PFCm_R_AgeXSex.nii.gz [626]
#   Added LOC_R_PCG_L_AgeXSex.nii.gz [569]
#   Added LOC_R_PCm_R_AgeXSex.nii.gz [528]
#  Output saved to /Volumes/AndrewElements/data/nki/tract_stats/dmn/glms/glm-age-sex

# %%
# Generate Pajek graphs

assert my_glm.create_pajek_graphs( suffix='-rft', edge_val='tsum', verbose=True, clobber=True )
# Out:
# glm-age-sex
#  Age
#   Wrote positive Pajek graph for Age
#   Wrote negative Pajek graph for Age
#  Sex
#   Wrote positive Pajek graph for Sex
#   Wrote negative Pajek graph for Sex
#  Age*Sex
#   Wrote positive Pajek graph for AgeXSex
#   Wrote negative Pajek graph for AgeXSex
# True
